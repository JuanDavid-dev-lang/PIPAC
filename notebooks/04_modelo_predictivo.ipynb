# %% [markdown]
# # 04 - Modelo predictivo
#
# Cuaderno base para entrenamiento, validacion y comparacion de modelos.

# %%
from src.model_training import build_model_pipeline, train_classification
from src.model_evaluation import load_model_metrics
