# %% [markdown]
# # 01 - EDA y exploracion de datos
#
# Cuaderno base para inspeccionar fuentes crudas, volumenes, columnas y calidad inicial.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DIR = PROJECT_ROOT / 'data' / '01_raw'
list(RAW_DIR.glob('*.csv'))
